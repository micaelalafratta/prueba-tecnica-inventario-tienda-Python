# %%
class TiendaOnline:
    def __init__(self):

        self.inventario = [] #lista de diccionarios  #la tienda empieza vacía de inventario
        self.ventas_totales = float(0) #la tienda empieza vacía de ventas

    
    def agregar_producto(self, nombre, precio, cantidad):
        print(nombre, precio, cantidad) #Print control
        for producto in self.inventario:  #bucle for para iterar productos
            print(f"Control de producto en inventario: {producto}")
            if nombre.lower() == producto["nombre"]: #Si hay coincidencia, ya existe.
                #Obtenemos el valor usando la CLAVE del diccionario, en este caso ["nombre"]
                print(f"{producto["nombre"]} ya existe")

                producto["cantidad"] = producto["cantidad"] + cantidad  
                #Si el producto ya existe, actualiza cantidad de producto. 
                #Cantidad existente actualizada usando la CLAVE del diccionario + cantidad nueva. Otra manera: +=cantidad
                print(f"Control de inventario, actualización de cantidad de producto: {self.inventario}")
                return  
        #🛑El código llega hasta aquí en el BUCLE FOR. Si el producto está en el inventario, entra en el BUCLE FOR. 
        

        #👇🏽Si no, el código sigue FUERA DEL BUCLE FOR:
        nuevo_producto = {"nombre": nombre.lower(), "precio" : precio, "cantidad" : cantidad}  #Como diccionario. Cada diccionario se convierte en un elemento de la lista self.inventario.
        print(f"Control de nuevo producto: {nuevo_producto}")
        self.inventario.append(nuevo_producto) #Añadir nuevo producto
        print(f"Control de inventario, actualización de nuevo producto: {self.inventario}")


    def ver_inventario(self):
        for producto in self.inventario: #bucle for para iterar productos
            print(f"Control de inventario: Nombre:'{producto["nombre"]}', Precio: {producto["precio"]}€, Cantidad: {producto["cantidad"]}") 


    def  buscar_producto(self, nombre):
        for producto in self.inventario:  #bucle for para iterar productos
            if nombre.lower() == producto["nombre"]:
                print(f"Nombre:'{producto["nombre"]}', Precio: {producto["precio"]}€, Cantidad: {producto["cantidad"]}")
                return
                  
        print(f"El producto introducido no existe") 
        #se ejecuta si BUCLE FOR no encuentra coincidencias
                

    def actualizar_stock(self, nombre, cantidad):
        for producto in self.inventario: 
            if nombre.lower() == producto["nombre"]:
                producto["cantidad"] = producto["cantidad"] + cantidad  #es lo mismo que +=cantidad
                print(f"La cantidad del producto '{producto["nombre"]}' ha sido actualizado. Nueva cantidad: {producto["cantidad"]}")
                return
        print("Error. El producto introducido no existe.")

            
    def eliminar_producto(self, nombre):
        for producto in self.inventario:
            if nombre.lower() == producto["nombre"]:
                self.inventario.remove(producto)
                print(f"El producto '{producto["nombre"]}' ha sido eliminado.")
                return
        print(f"Error: El producto introducido no existe.")

    def calcular_valor_inventario(self): 
        #No se usa self.ventas_totales porque se pide el valor del inventario, no el valor de las ventas totales. 
        #No se han realizado ventas porque no existe "carrito". 
        #Se crea una variable local para valor_inventario_total, en vez de usar self.ventas_totales. 
        valor_inventario_total = 0
        for producto in self.inventario:
           
           valor_producto = producto["precio"] * producto["cantidad"] 
           print(f"El valor del inventario del producto '{producto["nombre"]}' es: {valor_producto} €")
           
           valor_inventario_total += valor_producto
        print(f"El valor total del inventario es: {valor_inventario_total}€")

    #En caso de querer igualar el valor total del inventario (self.inventario) con el de las ventas (self.ventas_totales),
    #se haría de la siguiente manera: 

    # def calcular_valor_inventario(self): 
    #     for producto in self.inventario:
           
    #        valor_producto = producto["precio"] * producto["cantidad"] 
    #        print(f"El valor del inventario del producto '{producto["nombre"]}' es: {valor_producto} €")
           
    #        self.ventas_totales += valor_producto
    #     print(f"El valor total del inventario es: {self.ventas_totales}€")

# %% [markdown]
# ELEMENTOS FUERA DE LA CLASE: Se llama a la función desde fuera

# %%
tienda = TiendaOnline()     
#Crear una tienda que llame a la CLASE TiendaOnline()

# %% [markdown]
# 1. Agregar_producto(self, nombre, precio, cantidad):

# %%
tienda.agregar_producto("Camiseta", 12, 300) 
#El código llama por orden. Si no hay, añade producto. 

tienda.agregar_producto("Camisa", 24.99, 200)  
#Nuevo producto, no coincidencia con lo anterior.

tienda.agregar_producto("Polo", 25, 100)
tienda.agregar_producto("polo", 25, 15) 
#suma el producto a "Polo" porque .lower()

tienda.agregar_producto("Pantalón", 19.99, 250)
#Nuevo producto, no coincidencia con lo anterior.

tienda.agregar_producto("Calcetines", 2.99, 100)
#Nuevo producto, no coincidencia con lo anterior.
# Out:
# Camiseta 12 300
# Control de nuevo producto: {'nombre': 'camiseta', 'precio': 12, 'cantidad': 300}
# Control de inventario, actualización de nuevo producto: [{'nombre': 'camiseta', 'precio': 12, 'cantidad': 300}]
# Camisa 24.99 200
# Control de producto en inventario: {'nombre': 'camiseta', 'precio': 12, 'cantidad': 300}
# Control de nuevo producto: {'nombre': 'camisa', 'precio': 24.99, 'cantidad': 200}
# Control de inventario, actualización de nuevo producto: [{'nombre': 'camiseta', 'precio': 12, 'cantidad': 300}, {'nombre': 'camisa', 'precio': 24.99, 'cantidad': 200}]
# Polo 25 100
# Control de producto en inventario: {'nombre': 'camiseta', 'precio': 12, 'cantidad': 300}
# Control de producto en inventario: {'nombre': 'camisa', 'precio': 24.99, 'cantidad': 200}
# Control de nuevo producto: {'nombre': 'polo', 'precio': 25, 'cantidad': 100}
# ...

# %% [markdown]
# 2. Ver_inventario(self):

# %%
tienda.ver_inventario()  #ver inventario entero por productos
# Out:
# Control de inventario: Nombre:'camiseta', Precio: 12€, Cantidad: 300
# Control de inventario: Nombre:'camisa', Precio: 24.99€, Cantidad: 200
# Control de inventario: Nombre:'polo', Precio: 25€, Cantidad: 115
# Control de inventario: Nombre:'pantalón', Precio: 19.99€, Cantidad: 250
# Control de inventario: Nombre:'calcetines', Precio: 2.99€, Cantidad: 100

# %% [markdown]
# 3. Buscar_producto(self, nombre):

# %%
tienda.buscar_producto("Camiseta")
tienda.buscar_producto("Pantalón")
tienda.buscar_producto("Polo") #mayus o minus da igual porque .lower()
tienda.buscar_producto("Jarrón") #no existe
tienda.buscar_producto("camiseta") 
tienda.buscar_producto("polo") #mayus o minus da igual porque .lower()
# Out:
# Nombre:'camiseta', Precio: 12€, Cantidad: 300
# Nombre:'pantalón', Precio: 19.99€, Cantidad: 250
# Nombre:'polo', Precio: 25€, Cantidad: 115
# El producto introducido no existe
# Nombre:'camiseta', Precio: 12€, Cantidad: 300
# Nombre:'polo', Precio: 25€, Cantidad: 115

# %% [markdown]
# 4. Actualizar_stock(self, nombre, cantidad):

# %%
tienda.actualizar_stock("Camiseta", 3)
tienda.actualizar_stock("Calcetines", 20)
# Out:
# La cantidad del producto 'camiseta' ha sido actualizado. Nueva cantidad: 303
# La cantidad del producto 'calcetines' ha sido actualizado. Nueva cantidad: 120

# %%
tienda.actualizar_stock("Cojín", 20)  #El producto no existe
# Out:
# Error. El producto introducido no existe.

# %% [markdown]
# 5. Eliminar_producto(self, nombre):

# %%
tienda.eliminar_producto("Camiseta")
tienda.eliminar_producto("Pelota") #prueba producto no existe.
# Out:
# El producto 'camiseta' ha sido eliminado.
# Error: El producto introducido no existe.

# %%
tienda.ver_inventario() #Control para ver que "Camiseta" se ha eliminado
# Out:
# Control de inventario: Nombre:'camisa', Precio: 24.99€, Cantidad: 200
# Control de inventario: Nombre:'polo', Precio: 25€, Cantidad: 115
# Control de inventario: Nombre:'pantalón', Precio: 19.99€, Cantidad: 250
# Control de inventario: Nombre:'calcetines', Precio: 2.99€, Cantidad: 120

# %% [markdown]
# 6. Calcular_valor_inventario(self):

# %%
tienda.calcular_valor_inventario()
# Out:
# El valor del inventario del producto 'camisa' es: 4998.0 €
# El valor del inventario del producto 'polo' es: 2875 €
# El valor del inventario del producto 'pantalón' es: 4997.5 €
# El valor del inventario del producto 'calcetines' es: 358.8 €
# El valor total del inventario es: 13229.3€
