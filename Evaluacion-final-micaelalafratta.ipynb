# %%
class TiendaOnline:
    def __init__(self):

        self.inventario = [] #lista de diccionarios
        self.ventas_totales = 0 #la tienda empieza vacía de ventas

    
    def agregar_producto(self, nombre, precio, cantidad):
        for producto in self.inventario:  #bucle for para iterar productos
            print(f"Control de producto en inventario: {producto}")
            if nombre == producto["nombre"]: #Si hay coincidencia, ya existe.
                #Obtenemos el valor usando la CLAVE del diccionario, en este caso ["nombre"]
                print(f"{producto["nombre"]} ya existe")

                producto["cantidad"] = producto["cantidad"] + cantidad  
                #Actualizar cantidad de producto. 
                #Cantidad existente actualizada usando la CLAVE del diccionario + cantidad nueva
                print(f"Control de inventario, actualización de cantidad: {self.inventario}")
                return  
        #El código llega hasta aquí en el bucle for. 
        #Si el producto está en el inventario, entra en el bucle FOR. Si no, el código sigue:
            
        nuevo_producto = {"nombre": nombre, "precio" : precio, "cantidad" : cantidad}  #Como diccionario
        print(nombre, precio, cantidad) #Print control
        print(f"Control de nuevo producto: {nuevo_producto}")
        self.inventario.append(nuevo_producto) #Añadir nuevo producto
        print(f"Control de inventario, actualización de nuevo producto: {self.inventario}")


    def ver_inventario(self):
        for producto in self.inventario: #bucle for para iterar productos
            print(f"Control de inventario: {producto}")  #####añadir más detalles, con formato. con euros


    def  buscar_producto(self, nombre):
        for producto in self.inventario:  #bucle for para iterar productos
            if nombre == producto["nombre"]:
                print(f"El producto con nombre ''{nombre}'' existe")
                return
             #DEVUELVE "NO EXISTE POR CADA PRODUCTO QUE ENTRA Y NO IDENTIFICA EN ESA VUELTA AUNQUE EL PRODUCTO EXISTA"

              
        print(f"El producto introducido no existe") #se ejecuta si bucle for no encuentra coincidencias
                


    # def actualizar_stock(self, nombre, cantidad):

    # def eliminar_producto(self, nombre):

    # def   calcular_valor_inventario(self):

# %% [markdown]
# ELEMENTOS FUERA DE LA CLASE: Se llama a la función desde fuera

# %%
tienda = TiendaOnline()     
#Crear una tienda que llame a la CLASE TiendaOnline()

# %% [markdown]
# 1. Agregar_producto(self, nombre, precio, cantidad):

# %%
tienda.agregar_producto("Camiseta", 5, 2) 
#El código llama por orden. Si no hay, añade producto. 
tienda.agregar_producto("Camiseta", 5, 2) 
#El código vuelve a entrar y llama a la función. 
#En este caso, el producto ya existe. 
tienda.agregar_producto("Pantalón", 10, 8)
#Nuevo producto, no coincidencia con lo anterior.
tienda.agregar_producto("Polo", 20, 1)
# Out:
# Camiseta 5 2
# Control de nuevo producto: {'nombre': 'Camiseta', 'precio': 5, 'cantidad': 2}
# Control de inventario, actualización de nuevo producto: [{'nombre': 'Camiseta', 'precio': 5, 'cantidad': 2}]
# Control de producto en inventario: {'nombre': 'Camiseta', 'precio': 5, 'cantidad': 2}
# Camiseta ya existe
# Control de inventario, actualización de cantidad: [{'nombre': 'Camiseta', 'precio': 5, 'cantidad': 4}]
# Control de producto en inventario: {'nombre': 'Camiseta', 'precio': 5, 'cantidad': 4}
# Pantalón 10 8
# Control de nuevo producto: {'nombre': 'Pantalón', 'precio': 10, 'cantidad': 8}
# Control de inventario, actualización de nuevo producto: [{'nombre': 'Camiseta', 'precio': 5, 'cantidad': 4}, {'nombre': 'Pantalón', 'precio': 10, 'cantidad': 8}]
# Control de producto en inventario: {'nombre': 'Camiseta', 'precio': 5, 'cantidad': 4}
# Control de producto en inventario: {'nombre': 'Pantalón', 'precio': 10, 'cantidad': 8}
# Polo 20 1
# Control de nuevo producto: {'nombre': 'Polo', 'precio': 20, 'cantidad': 1}
# Control de inventario, actualización de nuevo producto: [{'nombre': 'Camiseta', 'precio': 5, 'cantidad': 4}, {'nombre': 'Pantalón', 'precio': 10, 'cantidad': 8}, {'nombre': 'Polo', 'precio': 20, 'cantidad': 1}]

# %% [markdown]
# 2. Ver_inventario(self):

# %%
tienda.ver_inventario()  #ver inventario entero por productos
# Out:
# Control de inventario: {'nombre': 'Camiseta', 'precio': 5, 'cantidad': 4}
# Control de inventario: {'nombre': 'Pantalón', 'precio': 10, 'cantidad': 8}
# Control de inventario: {'nombre': 'Polo', 'precio': 20, 'cantidad': 1}

# %% [markdown]
# 3. Buscar_producto(self, nombre):

# %%
tienda.buscar_producto("Camiseta")
tienda.buscar_producto("Pantalón")
tienda.buscar_producto("Polo")
tienda.buscar_producto("Jarrón")
# Out:
# El producto con nombre ''Camiseta'' existe
# El producto con nombre ''Pantalón'' existe
# El producto con nombre ''Polo'' existe
# El producto introducido no existe

# %% [markdown]
# 4. Actualizar_stock(self, nombre, cantidad):

# %% [markdown]
# 5. Eliminar_producto(self, nombre):

# %% [markdown]
# 6. Calcular_valor_inventario(self):
